# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn as sk

# %%
x = np.array([1,3,6,8])
y = np.array([1,2,3,4])

plt.plot(x,y)
# plt.show()

# %%
x = np.array([1,3,6,8])
y = np.array([1,2,3,4])
c= np.array(["red","blue","green","yellow"])
s = np.array([50,100,150,200])
plt.scatter(x,y,c=c,s=s)
plt.show()

# %%
x = np.array([1,3,6,8])
y = np.array([1,2,3,4])
c= np.array(["red","blue","green","yellow"])
s = np.array([50,100,150,200])
# plt.scatter(x,y,c=c,s=s,marker="dotted")
plt.plot(x,y,marker="D",linestyle="dotted")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.array([1,3,6,8])
y = np.array([1,2,3,4])

plt.plot(x,y)
plt.show()

# %%
x=np.array ([0,25,50,75,100])
y=np.array([1,2,3,4,5])
my_label=np.array(["a","b","c","d","e"])
c=np.array(["red","blue","green","yellow","black"])
plt.scatter(x,my_label,c=c)
plt.plot(x,y,marker="D",linestyle="dotted")

plt.show()

# %%
a = np.array(["ram","shyam","hari","gopal"])
b = np.array ([2000,3000,4000,5000])
plt.plot(a,b,marker="D",linestyle="dotted",ms=5) # ms ---> marker size

# %%
y = np.array([0,2,5,9])
plt.plot(y, "d:g",ms=20) # o is for  MARKER SIZE and g is for color we can use other color also like g,r,b,y etc..
plt.show()
