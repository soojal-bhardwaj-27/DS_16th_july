# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import StandardScaler,LabelEncoder,OneHotEncoder

# %%
df= pd.read_csv("laptopPrice.csv")

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
df.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     823.000000         823.000000         823.000000
# mean    76745.177400         315.301337          37.609964
# std     45101.790525        1047.382654         121.728017
# min     16990.000000           0.000000           0.000000
# 25%     46095.000000           0.000000           0.000000
# 50%     64990.000000          17.000000           2.000000
# 75%     89636.000000         139.500000          18.000000
# max    441990.000000       15279.000000        1947.000000

# %%
df.isnull()
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0    False            False           False            False   False
# 1    False            False           False            False   False
# 2    False            False           False            False   False
# 3    False            False           False            False   False
# 4    False            False           False            False   False
# ..     ...              ...             ...              ...     ...
# 818  False            False           False            False   False
# 819  False            False           False            False   False
# 820  False            False           False            False   False
# 821  False            False           False            False   False
# 822  False            False           False            False   False
#
#      ram_type    ssd    hdd     os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
df.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
df["brand"].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
df.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     823.000000         823.000000         823.000000
# mean    76745.177400         315.301337          37.609964
# std     45101.790525        1047.382654         121.728017
# min     16990.000000           0.000000           0.000000
# 25%     46095.000000           0.000000           0.000000
# 50%     64990.000000          17.000000           2.000000
# 75%     89636.000000         139.500000          18.000000
# max    441990.000000       15279.000000        1947.000000

# %%
dct = {
    'ASUS':1, 'Lenovo':2, 'acer':3, 'Avita':4, 'HP':5, 
    'DELL':6, 'MSI':7, 'APPLE':8
}

# %%
dct
# Out:
# {'ASUS': 1,
#  'Lenovo': 2,
#  'acer': 3,
#  'Avita': 4,
#  'HP': 5,
#  'DELL': 6,
#  'MSI': 7,
#  'APPLE': 8}

# %%
df["brand"]=df["brand"].map(dct)

# %%
df["brand"].unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
df
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0        1           Intel        Core i3            10th   4 GB     DDR4
# 1        2           Intel        Core i3            10th   4 GB     DDR4
# 2        2           Intel        Core i3            10th   4 GB     DDR4
# 3        1           Intel        Core i5            10th   8 GB     DDR4
# 4        1           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..     ...             ...            ...             ...    ...      ...
# 818      1             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819      1             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820      1             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821      1             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822      2             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
import sklearn 
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
obj = LabelEncoder()
df["brand"] = obj.fit_transform(df["brand"])
df["processor_brand"] = obj.fit_transform(df["processor_brand"])
df["processor_name"] = obj.fit_transform(df["processor_name"])
df["processor_gnrtn"] = obj.fit_transform(df["processor_gnrtn"])
df["ram_type"] = obj.fit_transform(df["ram_type"])
df["ssd"] = obj.fit_transform(df["ssd"])
df["hdd"] = obj.fit_transform(df["hdd"])
df["os"] = obj.fit_transform(df["os"])
df["os_bit"] = obj.fit_transform(df["os_bit"])
df["ram_gb"]  = obj.fit_transform(df["ram_gb"])

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        0                1               1                0       2
# 1        1                1               1                0       2
# 2        1                1               1                0       2
# 3        0                1               2                0       3
# 4        0                1               0                7       2
# ..     ...              ...             ...              ...     ...
# 818      0                0              10                7       2
# 819      0                0              10                7       2
# 820      0                0              10                7       2
# 821      0                0              10                7       2
# 822      1                0               8                0       3
#
#      ram_type  ssd  hdd  os  os_bit graphic_card_gb      weight     warranty  \
# ...

# %%
df.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
df.duplicated().sum(
    
)
# Out:
# np.int64(21)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# Length: 802, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("laptopPrice_cleaned.csv")

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        0                1               1                0       2
# 1        1                1               1                0       2
# 2        1                1               1                0       2
# 3        0                1               2                0       3
# 4        0                1               0                7       2
# ..     ...              ...             ...              ...     ...
# 818      0                0              10                7       2
# 819      0                0              10                7       2
# 820      0                0              10                7       2
# 821      0                0              10                7       2
# 822      1                0               8                0       3
#
#      ram_type  ssd  hdd  os  os_bit graphic_card_gb      weight     warranty  \
# ...

# %%
df["weight"] = obj.fit_transform(df["weight"])
df["Touchscreen"] = obj.fit_transform(df["Touchscreen"])
df["warranty"] = obj.fit_transform(df["warranty"])
df["msoffice"] = obj.fit_transform(df["msoffice"])
df["rating"] = obj.fit_transform(df["rating"])

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        0                1               1                0       2
# 1        1                1               1                0       2
# 2        1                1               1                0       2
# 3        0                1               2                0       3
# 4        0                1               0                7       2
# ..     ...              ...             ...              ...     ...
# 818      0                0              10                7       2
# 819      0                0              10                7       2
# 820      0                0              10                7       2
# 821      0                0              10                7       2
# 822      1                0               8                0       3
#
#      ram_type  ssd  hdd  os  os_bit graphic_card_gb  weight  warranty  \
# ...

# %%
df.to_csv("laptopPrice_final_cleaned.csv")

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        0                1               1                0       2
# 1        1                1               1                0       2
# 2        1                1               1                0       2
# 3        0                1               2                0       3
# 4        0                1               0                7       2
# ..     ...              ...             ...              ...     ...
# 818      0                0              10                7       2
# 819      0                0              10                7       2
# 820      0                0              10                7       2
# 821      0                0              10                7       2
# 822      1                0               8                0       3
#
#      ram_type  ssd  hdd  os  os_bit graphic_card_gb  weight  warranty  \
# ...

# %%
import sklearn 
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
df.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
x =df.drop('Price', axis=1) 
y =df[['Price']]

# %%
x
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        0                1               1                0       2
# 1        1                1               1                0       2
# 2        1                1               1                0       2
# 3        0                1               2                0       3
# 4        0                1               0                7       2
# ..     ...              ...             ...              ...     ...
# 818      0                0              10                7       2
# 819      0                0              10                7       2
# 820      0                0              10                7       2
# 821      0                0              10                7       2
# 822      1                0               8                0       3
#
#      ram_type  ssd  hdd  os  os_bit graphic_card_gb  weight  warranty  \
# ...

# %%
y
# Out:
#       Price
# 0     34649
# 1     38999
# 2     39999
# 3     69990
# 4     26990
# ..      ...
# 818  135990
# 819  144990
# 820  149990
# 821  142990
# 822   57490
#
# [802 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
x_train.shape ,y_train.shape, x_test.shape, y_test.shape
# Out:
# ((641, 18), (641, 1), (161, 18), (161, 1))

# %%
x_train
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 371      5                1               2                1       3
# 444      2                1               2                1       3
# 78       1                1               1                0       2
# 66       0                1               1                1       2
# 743      0                0               9                7       3
# ..     ...              ...             ...              ...     ...
# 784      1                0               9                7       2
# 196      2                1               2                7       3
# 650      5                0               7                7       2
# 575      2                1               3                0       0
# 705      0                0               8                7       2
#
#      ram_type  ssd  hdd  os  os_bit graphic_card_gb  weight  warranty  \
# ...

# %%
y_train
# Out:
#       Price
# 371   71290
# 444   57990
# 78    40990
# 66    39990
# 743   71990
# ..      ...
# 784  130990
# 196   50990
# 650   40590
# 575  159990
# 705   91990
#
# [641 rows x 1 columns]

# %%
x_test
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 8        1                1               2                0       2
# 257      2                1               2                1       3
# 87       4                1               1                1       3
# 432      0                1               2                0       3
# 15       4                1               1                1       3
# ..     ...              ...             ...              ...     ...
# 50       5                1               1                1       3
# 214      1                1               2                1       3
# 724      4                0               8                7       0
# 317      1                1               2                1       3
# 206      1                1               2                1       3
#
#      ram_type  ssd  hdd  os  os_bit graphic_card_gb  weight  warranty  \
# ...

# %%
y_test
# Out:
#      Price
# 8    49999
# 257  60990
# 87   42990
# 432  83990
# 15   56490
# ..     ...
# 50   41990
# 214  61999
# 724  59999
# 317  70990
# 206  49490
#
# [161 rows x 1 columns]

# %%
# from sklearn.svm import SVC ,SVR
# sv = SVC()
# sv.fit(x_train, y_train)

# %%
df["graphic_card_gb"] = obj.fit_transform(df["graphic_card_gb"])

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        0                1               1                0       2
# 1        1                1               1                0       2
# 2        1                1               1                0       2
# 3        0                1               2                0       3
# 4        0                1               0                7       2
# ..     ...              ...             ...              ...     ...
# 818      0                0              10                7       2
# 819      0                0              10                7       2
# 820      0                0              10                7       2
# 821      0                0              10                7       2
# 822      1                0               8                0       3
#
#      ram_type  ssd  hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
df.to_csv("laptopPrice_ok_cleaned.csv")

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        0                1               1                0       2
# 1        1                1               1                0       2
# 2        1                1               1                0       2
# 3        0                1               2                0       3
# 4        0                1               0                7       2
# ..     ...              ...             ...              ...     ...
# 818      0                0              10                7       2
# 819      0                0              10                7       2
# 820      0                0              10                7       2
# 821      0                0              10                7       2
# 822      1                0               8                0       3
#
#      ram_type  ssd  hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
x =df.drop('Price', axis=1) 
y =df[['Price']]

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        0                1               1                0       2
# 1        1                1               1                0       2
# 2        1                1               1                0       2
# 3        0                1               2                0       3
# 4        0                1               0                7       2
# ..     ...              ...             ...              ...     ...
# 818      0                0              10                7       2
# 819      0                0              10                7       2
# 820      0                0              10                7       2
# 821      0                0              10                7       2
# 822      1                0               8                0       3
#
#      ram_type  ssd  hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
from sklearn.model_selection import train_test_split 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
x_test , y_test , x_train , y_train
# Out:
# (     brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
#  8        1                1               2                0       2
#  257      2                1               2                1       3
#  87       4                1               1                1       3
#  432      0                1               2                0       3
#  15       4                1               1                1       3
#  ..     ...              ...             ...              ...     ...
#  50       5                1               1                1       3
#  214      1                1               2                1       3
#  724      4                0               8                7       0
#  317      1                1               2                1       3
#  206      1                1               2                1       3
#
#       ram_type  ssd  hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
x
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        0                1               1                0       2
# 1        1                1               1                0       2
# 2        1                1               1                0       2
# 3        0                1               2                0       3
# 4        0                1               0                7       2
# ..     ...              ...             ...              ...     ...
# 818      0                0              10                7       2
# 819      0                0              10                7       2
# 820      0                0              10                7       2
# 821      0                0              10                7       2
# 822      1                0               8                0       3
#
#      ram_type  ssd  hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
y
# Out:
#       Price
# 0     34649
# 1     38999
# 2     39999
# 3     69990
# 4     26990
# ..      ...
# 818  135990
# 819  144990
# 820  149990
# 821  142990
# 822   57490
#
# [802 rows x 1 columns]

# %%
from sklearn.svm import SVC ,SVR
sr = SVR()
sr.fit(x_train, y_train)
# Out:
# c:\Users\Sooja\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()
