# %%
import pandas as pd

# %%
import sklearn

# %%
df = pd.read_csv("bike_clean.csv")

# %%
df
# Out:
#       Unnamed: 0  bike_name     price  city  kms_driven  owner  age  power  \
# 0              0        401   35000.0     6     17654.0      0    2      2
# 1              1        295  119900.0   118     11000.0      0    3     19
# 2              2        411  600000.0   118       110.0      0    7     28
# 3              3        375   65000.0    44     16329.0      0    3      9
# 4              4        426   80000.0    44     10000.0      0    2      6
# ...          ...        ...       ...   ...         ...    ...  ...    ...
# 7319        9362        141   25000.0   118     48587.0      0    7      6
# 7320        9369          9   35000.0    44     60000.0      0    8     11
# 7321        9370        110  450000.0   211      3430.0      0    3     29
# 7322        9371         44  139000.0   185     21300.0      0    3     21
# 7323        9372         15   80000.0   185      7127.0      0    4     11
#
#       brand
# 0        19
# 1        17
# 2        20
# 3        19
# ...

# %%
# df.drop("Unnamed: 0","bike_name","city", axis=1, inplace=True)
df.drop(['Unnamed: 0','bike_name', 'city'], axis=1, inplace=True)

# %%
df
# Out:
#          price  kms_driven  owner  age  power  brand
# 0      35000.0     17654.0      0    2      2     19
# 1     119900.0     11000.0      0    3     19     17
# 2     600000.0       110.0      0    7     28     20
# 3      65000.0     16329.0      0    3      9     19
# 4      80000.0     10000.0      0    2      6     21
# ...        ...         ...    ...  ...    ...    ...
# 7319   25000.0     48587.0      0    7      6      5
# 7320   35000.0     60000.0      0    8     11      1
# 7321  450000.0      3430.0      0    3     29      4
# 7322  139000.0     21300.0      0    3     21      1
# 7323   80000.0      7127.0      0    4     11      1
#
# [7324 rows x 6 columns]

# %%
x =df.drop('price', axis=1) 
y =df[['price']]

# %%
x
# Out:
#       kms_driven  owner  age  power  brand
# 0        17654.0      0    2      2     19
# 1        11000.0      0    3     19     17
# 2          110.0      0    7     28     20
# 3        16329.0      0    3      9     19
# 4        10000.0      0    2      6     21
# ...          ...    ...  ...    ...    ...
# 7319     48587.0      0    7      6      5
# 7320     60000.0      0    8     11      1
# 7321      3430.0      0    3     29      4
# 7322     21300.0      0    3     21      1
# 7323      7127.0      0    4     11      1
#
# [7324 rows x 5 columns]

# %%
y
# Out:
#          price
# 0      35000.0
# 1     119900.0
# 2     600000.0
# 3      65000.0
# 4      80000.0
# ...        ...
# 7319   25000.0
# 7320   35000.0
# 7321  450000.0
# 7322  139000.0
# 7323   80000.0
#
# [7324 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
x_train.shape , y_train.shape, x_test.shape, y_test.shape
# Out:
# ((5859, 5), (5859, 1), (1465, 5), (1465, 1))

# %%
x_train
# Out:
#       kms_driven  owner  age  power  brand
# 2434     55268.0      0    4      7      6
# 283      22560.0      0   10      6      1
# 2975     38700.0      0    8     11      1
# 4184     38000.0      0    5      2      5
# 557      13935.0      0    4      6      1
# ...          ...    ...  ...    ...    ...
# 4931     22778.0      0    6      6      1
# 3264     11000.0      0    3     21      1
# 1653     16800.0      0    2     23     17
# 2607     14500.0      0    3     20     11
# 2732     44030.0      1   14      3     18
#
# [5859 rows x 5 columns]

# %%
from sklearn.linear_model import LinearRegression
lr =LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test, y_test)
# Out:
# 0.5546235323664166

# %%
lr.score(x_train, y_train)
# Out:
# 0.5072234365156074

# %%
# sv.score(x_train, y_train)

# %%
# sv.score(x_test, y_test)

# %%
pred = lr.predict(x_test)

# %%
pred
# Out:
# array([[ 45787.25105432],
#        [186178.15934744],
#        [ 25317.98640926],
#        ...,
#        [-10073.8028835 ],
#        [  1384.39489129],
#        [194232.99589388]], shape=(1465, 1))

# %%
y_test
# Out:
#          price
# 2134   80000.0
# 4281  150000.0
# 7290   30000.0
# 1564   90000.0
# 7263   22000.0
# ...        ...
# 4198  105000.0
# 5923   25000.0
# 4958   25000.0
# 7067   20000.0
# 5392   70000.0
#
# [1465 rows x 1 columns]

# %%
from sklearn.svm import SVR ,SVC
sv = SVR()
sv.fit(x_train, y_train)
# Out:
# c:\Users\Sooja\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
pred = sv.predict(x_test)

# %%
pred
# Out:
# array([53734.30088017, 55023.54085341, 54150.51757531, ...,
#        54603.39343904, 54692.33969485, 54133.77704238], shape=(1465,))

# %%
y_test
# Out:
#          price
# 2134   80000.0
# 4281  150000.0
# 7290   30000.0
# 1564   90000.0
# 7263   22000.0
# ...        ...
# 4198  105000.0
# 5923   25000.0
# 4958   25000.0
# 7067   20000.0
# 5392   70000.0
#
# [1465 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd

# %%
df = pd.read_csv("bike_clean.csv")

# %%
df
# Out:
#          price  kms_driven  owner  age  power  brand
# 0      35000.0     17654.0      0    2      2     19
# 1     119900.0     11000.0      0    3     19     17
# 2     600000.0       110.0      0    7     28     20
# 3      65000.0     16329.0      0    3      9     19
# 4      80000.0     10000.0      0    2      6     21
# ...        ...         ...    ...  ...    ...    ...
# 7319   25000.0     48587.0      0    7      6      5
# 7320   35000.0     60000.0      0    8     11      1
# 7321  450000.0      3430.0      0    3     29      4
# 7322  139000.0     21300.0      0    3     21      1
# 7323   80000.0      7127.0      0    4     11      1
#
# [7324 rows x 6 columns]

# %%
# x = df.drop(columns=["price", "Unnamed: 0", "bike_name", "city"])
# y = df["price"]

# %%
x
# Out:
#       kms_driven  owner  age  power  brand
# 0        17654.0      0    2      2     19
# 1        11000.0      0    3     19     17
# 2          110.0      0    7     28     20
# 3        16329.0      0    3      9     19
# 4        10000.0      0    2      6     21
# ...          ...    ...  ...    ...    ...
# 7319     48587.0      0    7      6      5
# 7320     60000.0      0    8     11      1
# 7321      3430.0      0    3     29      4
# 7322     21300.0      0    3     21      1
# 7323      7127.0      0    4     11      1
#
# [7324 rows x 5 columns]

# %%
y
# Out:
#          price
# 0      35000.0
# 1     119900.0
# 2     600000.0
# 3      65000.0
# 4      80000.0
# ...        ...
# 7319   25000.0
# 7320   35000.0
# 7321  450000.0
# 7322  139000.0
# 7323   80000.0
#
# [7324 rows x 1 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# c:\Users\Sooja\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neighbors\_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.018430034129692834

# %%
# model = LogisticRegression(max_iter=1000)  # add max_iter in case of convergence issues
# model.fit(x_train, y_train)
# y_pred_lr = model.predict(x_test)
# accuracy_score(y_test, y_pred_lr)

# %%
# from sklearn.tree import DecisionTreeRegression
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(x_train, y_train)
y_pred_dt = model.predict(x_test)

# %%
y_pred_dt
# Out:
# array([ 33000., 140000.,  30000., ...,  30000.,  18000., 110000.],
#       shape=(1465,))

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=100, random_state=42)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
rf.fit(x_train, y_train)
y_pred_rf = rf.predict(x_test)
# accuracy_score(y_test, y_pred_rf)
# Out:
# c:\Users\Sooja\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
y_pred_rf
# Out:
# array([ 35876.       , 144826.       ,  27404.       , ...,
#         29196.9047619,  20444.74     , 108377.62     ], shape=(1465,))
